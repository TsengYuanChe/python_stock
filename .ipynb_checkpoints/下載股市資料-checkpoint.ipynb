# %%
import yfinance as yf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
stock = yf.download("GOOG","2019-09-15","2019-09-25")
stock.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2019-09-16  61.476002  61.978001  61.280499  61.564999  61.564999  21066000
# 2019-09-17  61.520000  61.750000  61.184502  61.457500  61.457500  19102000
# 2019-09-18  61.375500  61.780499  60.826500  61.620499  61.620499  22702000
# 2019-09-19  61.603001  62.222000  61.601002  61.935501  61.935501  19920000
# 2019-09-20  61.655998  62.166000  61.153999  61.496498  61.496498  45400000

# %%
stock.to_csv("stock.csv")

# %%
fig = plt.figure(figsize = (10, 5))
plt.plot(stock["Open"],color = "red")
plt.title("Google open price")
plt.show();

# %%
fig = plt.figure(figsize = (10, 5))
plt.plot(stock["Open"],color = "red")
plt.plot(stock["Close"],color = "green")
plt.plot(stock["High"],color = "blue")
plt.plot(stock["Low"],color = "black")
plt.title("Google open price")
plt.show();
