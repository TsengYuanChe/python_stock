# %%
import twstock
import requests as r
import pandas as pd

# %%
stock = twstock.realtime.get('2330')
stock
# Out:
# {'timestamp': 1706250600.0,
#  'info': {'code': '2330',
#   'channel': '2330.tw',
#   'name': '台積電',
#   'fullname': '台灣積體電路製造股份有限公司',
#   'time': '2024-01-26 14:30:00'},
#  'realtime': {'latest_trade_price': '644.0000',
#   'trade_volume': '4494',
#   'accumulate_trade_volume': '40985',
#   'best_bid_price': ['644.0000',
#    '643.0000',
#    '642.0000',
#    '641.0000',
#    '640.0000'],
#   'best_bid_volume': ['811', '313', '186', '424', '324'],
#   'best_ask_price': ['645.0000',
#    '646.0000',
#    '647.0000',
#    '648.0000',
#    '649.0000'],
#   'best_ask_volume': ['2919', '3009', '1217', '1725', '687'],
#   'open': '644.0000',
#   'high': '646.0000',
#   'low': '639.0000'},
#  'success': True}

# %%
stock['success'] == True
# Out:
# True

# %%
"台股即時報價" if stock['success'] == True else "不是台股即時報價"
# Out:
# '台股即時報價'

# %%
stock = pd.DataFrame(stock)
stock
# Out:
#                             timestamp                 info  \
# code                     1.706251e+09                 2330
# channel                  1.706251e+09              2330.tw
# name                     1.706251e+09                  台積電
# fullname                 1.706251e+09       台灣積體電路製造股份有限公司
# time                     1.706251e+09  2024-01-26 14:30:00
# latest_trade_price       1.706251e+09                  NaN
# trade_volume             1.706251e+09                  NaN
# accumulate_trade_volume  1.706251e+09                  NaN
# best_bid_price           1.706251e+09                  NaN
# best_bid_volume          1.706251e+09                  NaN
# best_ask_price           1.706251e+09                  NaN
# best_ask_volume          1.706251e+09                  NaN
# open                     1.706251e+09                  NaN
# high                     1.706251e+09                  NaN
# low                      1.706251e+09                  NaN
#
#                                                                   realtime  \
# code                                                                   NaN
# channel                                                                NaN
# name                                                                   NaN
# fullname                                                               NaN
# time                                                                   NaN
# latest_trade_price                                                644.0000
# trade_volume                                                          4494
# accumulate_trade_volume                                              40985
# best_bid_price           [644.0000, 643.0000, 642.0000, 641.0000, 640.0...
# best_bid_volume                                  [811, 313, 186, 424, 324]
# best_ask_price           [645.0000, 646.0000, 647.0000, 648.0000, 649.0...
# best_ask_volume                              [2919, 3009, 1217, 1725, 687]
# open                                                              644.0000
# high                                                              646.0000
# low                                                               639.0000
#
#                          success
# code                        True
# channel                     True
# name                        True
# fullname                    True
# time                        True
# latest_trade_price          True
# trade_volume                True
# accumulate_trade_volume     True
# best_bid_price              True
# best_bid_volume             True
# best_ask_price              True
# best_ask_volume             True
# open                        True
# high                        True
# low                         True

# %%
stock_info = stock.iloc[0:5, 1]
stock_info
# Out:
# code                       2330
# channel                 2330.tw
# name                        台積電
# fullname         台灣積體電路製造股份有限公司
# time        2024-01-26 14:30:00
# Name: info, dtype: object

# %%
stock_realtime = stock.iloc[5:, 2]
stock_realtime
# Out:
# latest_trade_price                                                  644.0000
# trade_volume                                                            4494
# accumulate_trade_volume                                                40985
# best_bid_price             [644.0000, 643.0000, 642.0000, 641.0000, 640.0...
# best_bid_volume                                    [811, 313, 186, 424, 324]
# best_ask_price             [645.0000, 646.0000, 647.0000, 648.0000, 649.0...
# best_ask_volume                                [2919, 3009, 1217, 1725, 687]
# open                                                                644.0000
# high                                                                646.0000
# low                                                                 639.0000
# Name: realtime, dtype: object

# %%
stock_data = stock_info._append(stock_realtime, ignore_index = True)
stock_data
# Out:
# 0                                                  2330
# 1                                               2330.tw
# 2                                                   台積電
# 3                                        台灣積體電路製造股份有限公司
# 4                                   2024-01-26 14:30:00
# 5                                              644.0000
# 6                                                  4494
# 7                                                 40985
# 8     [644.0000, 643.0000, 642.0000, 641.0000, 640.0...
# 9                             [811, 313, 186, 424, 324]
# 10    [645.0000, 646.0000, 647.0000, 648.0000, 649.0...
# 11                        [2919, 3009, 1217, 1725, 687]
# 12                                             644.0000
# 13                                             646.0000
# 14                                             639.0000
# dtype: object

# %%
stock['data'] = list(stock_data)
stock
# Out:
#                             timestamp                 info  \
# code                     1.706251e+09                 2330
# channel                  1.706251e+09              2330.tw
# name                     1.706251e+09                  台積電
# fullname                 1.706251e+09       台灣積體電路製造股份有限公司
# time                     1.706251e+09  2024-01-26 14:30:00
# latest_trade_price       1.706251e+09                  NaN
# trade_volume             1.706251e+09                  NaN
# accumulate_trade_volume  1.706251e+09                  NaN
# best_bid_price           1.706251e+09                  NaN
# best_bid_volume          1.706251e+09                  NaN
# best_ask_price           1.706251e+09                  NaN
# best_ask_volume          1.706251e+09                  NaN
# open                     1.706251e+09                  NaN
# high                     1.706251e+09                  NaN
# low                      1.706251e+09                  NaN
#
#                                                                   realtime  \
# code                                                                   NaN
# channel                                                                NaN
# name                                                                   NaN
# fullname                                                               NaN
# time                                                                   NaN
# latest_trade_price                                                644.0000
# trade_volume                                                          4494
# accumulate_trade_volume                                              40985
# best_bid_price           [644.0000, 643.0000, 642.0000, 641.0000, 640.0...
# best_bid_volume                                  [811, 313, 186, 424, 324]
# best_ask_price           [645.0000, 646.0000, 647.0000, 648.0000, 649.0...
# best_ask_volume                              [2919, 3009, 1217, 1725, 687]
# open                                                              644.0000
# high                                                              646.0000
# low                                                               639.0000
#
#                          success  \
# code                        True
# channel                     True
# name                        True
# fullname                    True
# time                        True
# latest_trade_price          True
# trade_volume                True
# accumulate_trade_volume     True
# best_bid_price              True
# best_bid_volume             True
# best_ask_price              True
# best_ask_volume             True
# open                        True
# high                        True
# low                         True
#
#                                                                       data
# code                                                                  2330
# channel                                                            2330.tw
# name                                                                   台積電
# fullname                                                    台灣積體電路製造股份有限公司
# time                                                   2024-01-26 14:30:00
# latest_trade_price                                                644.0000
# trade_volume                                                          4494
# accumulate_trade_volume                                              40985
# best_bid_price           [644.0000, 643.0000, 642.0000, 641.0000, 640.0...
# best_bid_volume                                  [811, 313, 186, 424, 324]
# best_ask_price           [645.0000, 646.0000, 647.0000, 648.0000, 649.0...
# best_ask_volume                              [2919, 3009, 1217, 1725, 687]
# open                                                              644.0000
# high                                                              646.0000
# low                                                               639.0000

# %%
stock = stock.drop(['timestamp', 'info', 'realtime', 'success'], axis = 1)
stock
# Out:
#                                                                       data
# code                                                                  2330
# channel                                                            2330.tw
# name                                                                   台積電
# fullname                                                    台灣積體電路製造股份有限公司
# time                                                   2024-01-26 14:30:00
# latest_trade_price                                                644.0000
# trade_volume                                                          4494
# accumulate_trade_volume                                              40985
# best_bid_price           [644.0000, 643.0000, 642.0000, 641.0000, 640.0...
# best_bid_volume                                  [811, 313, 186, 424, 324]
# best_ask_price           [645.0000, 646.0000, 647.0000, 648.0000, 649.0...
# best_ask_volume                              [2919, 3009, 1217, 1725, 687]
# open                                                              644.0000
# high                                                              646.0000
# low                                                               639.0000

# %%
stock = stock.T
stock
# Out:
#       code  channel name        fullname                 time  \
# data  2330  2330.tw  台積電  台灣積體電路製造股份有限公司  2024-01-26 14:30:00
#
#      latest_trade_price trade_volume accumulate_trade_volume  \
# data           644.0000         4494                   40985
#
#                                          best_bid_price  \
# data  [644.0000, 643.0000, 642.0000, 641.0000, 640.0...
#
#                 best_bid_volume  \
# data  [811, 313, 186, 424, 324]
#
#                                          best_ask_price  \
# data  [645.0000, 646.0000, 647.0000, 648.0000, 649.0...
#
#                     best_ask_volume      open      high       low
# data  [2919, 3009, 1217, 1725, 687]  644.0000  646.0000  639.0000

# %%
stock.columns = ['股票代碼', '股票代碼全', '股票名稱', '公司名', '下載時間', '最新成交量', '成交量', '累計成交量', '最佳5檔賣出價', '最佳5檔賣出量', '最佳5檔買進價', '最佳5檔買進量', '開盤價', '最高價', '最低價']
stock
# Out:
#       股票代碼    股票代碼全 股票名稱             公司名                 下載時間     最新成交量   成交量  \
# data  2330  2330.tw  台積電  台灣積體電路製造股份有限公司  2024-01-26 14:30:00  644.0000  4494
#
#       累計成交量                                            最佳5檔賣出價  \
# data  40985  [644.0000, 643.0000, 642.0000, 641.0000, 640.0...
#
#                         最佳5檔賣出量  \
# data  [811, 313, 186, 424, 324]
#
#                                                 最佳5檔買進價  \
# data  [645.0000, 646.0000, 647.0000, 648.0000, 649.0...
#
#                             最佳5檔買進量       開盤價       最高價       最低價
# data  [2919, 3009, 1217, 1725, 687]  644.0000  646.0000  639.0000

# %%
stock_multi = twstock.realtime.get(['2330', '2454', '0050'])
stock_multi
# Out:
# {'2330': {'timestamp': 1706250600.0,
#   'info': {'code': '2330',
#    'channel': '2330.tw',
#    'name': '台積電',
#    'fullname': '台灣積體電路製造股份有限公司',
#    'time': '2024-01-26 14:30:00'},
#   'realtime': {'latest_trade_price': '644.0000',
#    'trade_volume': '4494',
#    'accumulate_trade_volume': '40985',
#    'best_bid_price': ['644.0000',
#     '643.0000',
#     '642.0000',
#     '641.0000',
#     '640.0000'],
#    'best_bid_volume': ['811', '313', '186', '424', '324'],
#    'best_ask_price': ['645.0000',
#     '646.0000',
#     '647.0000',
#     '648.0000',
#     '649.0000'],
#    'best_ask_volume': ['2919', '3009', '1217', '1725', '687'],
#    'open': '644.0000',
#    'high': '646.0000',
#    'low': '639.0000'},
#   'success': True},
#  '2454': {'timestamp': 1706250600.0,
#   'info': {'code': '2454',
#    'channel': '2454.tw',
#    'name': '聯發科',
#    'fullname': '聯發科技股份有限公司',
#    'time': '2024-01-26 14:30:00'},
#   'realtime': {'latest_trade_price': '936.0000',
#    'trade_volume': '543',
#    'accumulate_trade_volume': '5248',
#    'best_bid_price': ['935.0000',
#     '934.0000',
#     '933.0000',
#     '932.0000',
#     '931.0000'],
#    'best_bid_volume': ['14', '12', '37', '41', '132'],
#    'best_ask_price': ['936.0000',
#     '937.0000',
#     '938.0000',
#     '939.0000',
#     '940.0000'],
#    'best_ask_volume': ['33', '118', '152', '110', '100'],
#    'open': '936.0000',
#    'high': '939.0000',
#    'low': '928.0000'},
#   'success': True},
#  '0050': {'timestamp': 1706250600.0,
#   'info': {'code': '0050',
#    'channel': '0050.tw',
#    'name': '元大台灣50',
#    'fullname': '元大台灣卓越50證券投資信託基金',
#    'time': '2024-01-26 14:30:00'},
#   'realtime': {'latest_trade_price': '135.6500',
#    'trade_volume': '405',
#    'accumulate_trade_volume': '15804',
#    'best_bid_price': ['135.6000',
#     '135.5500',
#     '135.5000',
#     '135.4500',
#     '135.4000'],
#    'best_bid_volume': ['303', '332', '189', '221', '280'],
#    'best_ask_price': ['135.6500',
#     '135.7000',
#     '135.7500',
#     '135.8000',
#     '135.8500'],
#    'best_ask_volume': ['5', '40', '70', '469', '356'],
#    'open': '135.6500',
#    'high': '135.9500',
#    'low': '135.3000'},
#   'success': True},
#  'success': True}

# %%
pd.DataFrame(stock_multi)
# Out:
#                                                         2330  \
# timestamp                                       1706250600.0
# info       {'code': '2330', 'channel': '2330.tw', 'name':...
# realtime   {'latest_trade_price': '644.0000', 'trade_volu...
# success                                                 True
#
#                                                         2454  \
# timestamp                                       1706250600.0
# info       {'code': '2454', 'channel': '2454.tw', 'name':...
# realtime   {'latest_trade_price': '936.0000', 'trade_volu...
# success                                                 True
#
#                                                         0050  success
# timestamp                                       1706250600.0     True
# info       {'code': '0050', 'channel': '0050.tw', 'name':...     True
# realtime   {'latest_trade_price': '135.6500', 'trade_volu...     True
# success                                                 True     True

# %%
df = stock_multi['2330']
df
# Out:
# {'timestamp': 1706250600.0,
#  'info': {'code': '2330',
#   'channel': '2330.tw',
#   'name': '台積電',
#   'fullname': '台灣積體電路製造股份有限公司',
#   'time': '2024-01-26 14:30:00'},
#  'realtime': {'latest_trade_price': '644.0000',
#   'trade_volume': '4494',
#   'accumulate_trade_volume': '40985',
#   'best_bid_price': ['644.0000',
#    '643.0000',
#    '642.0000',
#    '641.0000',
#    '640.0000'],
#   'best_bid_volume': ['811', '313', '186', '424', '324'],
#   'best_ask_price': ['645.0000',
#    '646.0000',
#    '647.0000',
#    '648.0000',
#    '649.0000'],
#   'best_ask_volume': ['2919', '3009', '1217', '1725', '687'],
#   'open': '644.0000',
#   'high': '646.0000',
#   'low': '639.0000'},
#  'success': True}
